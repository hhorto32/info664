# %%
money_coffee = [4.35, 14.20, 11.70, 3.50, 3.50, 6.53, 0.00] 
print (money_coffee)
# Out:
# [4.35, 14.2, 11.7, 3.5, 3.5, 6.53, 0.0]

# %%
steps_taken = [13681, 12465, 14291, 8916, 6244, 6886, 19377, 11020]
print (steps_taken)
# Out:
# [13681, 12465, 14291, 8916, 6244, 6886, 19377, 11020]

# %%
wordle_score = [5,4,6, 3, 5, 5, 3, 6]
print(wordle_score)
# Out:
# [5, 4, 6, 3, 5, 5, 3, 6]

# %%
wordle_score.sort()
print(wordle_score)
# Out:
# [3, 3, 4, 5, 5, 5, 6, 6]

# %%
steps_taken.sort(reverse = True)
print(steps_taken)
# Out:
# [19377, 14291, 13681, 12465, 11020, 8916, 6886, 6244]

# %%
new_coffee = 4.74
print(new_coffee)
# Out:
# 4.74

# %%
money_coffee.append(new_coffee)
print(money_coffee)

# %% [markdown]
# Googled (extend) this one because I wanted to see how I could combine two lists.

# %%
new_coffee_list = [4.74, 1.47, 4.74]
money_coffee.extend(new_coffee_list)
print(money_coffee)
# Out:
# [4.35, 14.2, 11.7, 3.5, 3.5, 6.53, 0.0, 4.74, 4.74, 1.47, 4.74]
